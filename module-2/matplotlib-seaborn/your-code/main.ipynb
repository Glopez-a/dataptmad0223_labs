# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt   # conda install matplotlib

# seaborn
import seaborn as sns   # conda install seaborn

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
z
# Out:
# array([   0,    1,    4,    9,   16,   25,   36,   49,   64,   81,  100,
#         121,  144,  169,  196,  225,  256,  289,  324,  361,  400,  441,
#         484,  529,  576,  625,  676,  729,  784,  841,  900,  961, 1024,
#        1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849,
#        1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916,
#        3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225,
#        4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776,
#        5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569,
#        7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604,
#        9801])

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

fig = plt.figure()
# axes object

ax = plt.axes(arg = (0,0,1,1),
              projection = None,
              aspect =0.5)
print(type(ax))
plt.plot(x,y)
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
plt.plot(x, y)

# %%
plt.plot(x, z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(ncols = 2,
                       nrows = 1,
                       figsize= (11,5))


ax[0].plot(x,y, dashes=[6, 2], color="Red")
ax[0].lines[0].set_linewidth(5)

ax[1].plot(x,z)
a = plt
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
k = 2.71**x
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(10,5))
line1, = ax[0].plot(x, k)
line2, = ax[0].plot(x, z)
ax[1].set_yscale('log')
line1, = ax[1].plot(x, k)
line2, = ax[1].plot(x, z)
ax[0].legend(['e^x', 'x^2'])
ax[1].legend(['e^x', 'x^2'])

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit2 = pd.read_csv("../data/fitbit2.csv")
fitbit2
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

a = fitbit2.groupby(['Months_encoded'])[['Steps']].mean()
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
b = fitbit2.groupby(['Work_or_Weekend'])[['Steps']].mean()
fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(12,4))


sns.barplot(x='Months_encoded', y="Steps", data=fitbit2, ax=ax[0])
sns.barplot(x='Months_encoded', y="Steps", hue='Work_or_Weekend', data=fitbit2, ax=ax[1], palette="GnBu")
# Out:
# <Axes: xlabel='Months_encoded', ylabel='Steps'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
for i in ['Lightly Active', 'Very Active', 'Sedentary']:
    sns.jointplot(x='Minutes ' + i, y='Steps', data=fitbit2)

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("../data/titanic.csv")

titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(exclude='object')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
plt.figure(figsize=(12,6))
sns.histplot(x='Age', bins=30, data=titanic, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x='Age', bins=30, data=titanic, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(12,5))
sns.histplot(x='Age', bins=10, data=titanic, kde=True, ax=ax[0])
sns.histplot(x='Age', bins=20, data=titanic, kde=True, ax=ax[1])
sns.histplot(x='Age', bins=50, data=titanic, kde=True, ax=ax[2])
sns.histplot(x='Age', bins=50, hue='Survived', data=titanic, kde=True, ax=ax[3])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here


fig, ax = plt.subplots(2,2,figsize=(13,10))
sns.histplot(x='Age', bins=50, hue='Gender', data=titanic, kde=True, ax=ax[0][1])
sns.histplot(x='Gender', data=titanic, ax=ax[0][0])
titanic2 = titanic[titanic['Gender'] == 'female']
sns.histplot(x='Age', bins=50, hue='Survived', data=titanic2, kde=True, ax=ax[1][0]).set(title='Female survived distribution')
titanic3 = titanic[titanic['Gender'] == 'male']
sns.histplot(x='Age', bins=50, hue='Survived', data=titanic3, kde=True, ax=ax[1][1]).set(title='Male survived distribution')
# Out:
# [Text(0.5, 1.0, 'Male survived distribution')]

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x='Pclass', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# your code here
fig, ax = plt.subplots(1,1,figsize=(13,5))
titanic2 = titanic[titanic['Gender'] == 'female']
sns.countplot(x='Pclass', hue='Survived', data=titanic, ax=ax, palette="GnBu")
titanic3 = titanic[titanic['Gender'] == 'male']

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.histplot(x='Age', bins=50, data=titanic, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here
sns.jointplot(x='Age', y='Fare', data=titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
titanic['Gender'].replace(['female','male'],[0,1],inplace=True)
sns.heatmap(titanic.corr(numeric_only=True), vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Como curiosidad, tuvo más relevancia para sobrevivir, el sexo de la persona que la clase social.
Las mujeres y los niños primero.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
#plt.figure(figsize=(20,10))
#sns.color_palette("flare", as_cmap=True)
#sns.countplot(x='Age', hue='Pclass', data=titanic)
#sns.histplot(x='Age', bins=30, hue='Pclass', data=titanic, kde=True)
sns.kdeplot(x='Age', hue='Pclass', data=titanic)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(data=titanic, row='Gender')
g.map_dataframe(sns.histplot, x="Age")
